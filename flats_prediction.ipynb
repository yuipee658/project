# %% [markdown]
# В своем проекте я создам модель для прогнозирования цены на квартиру в Москве. В роли обучающих данных я использую dataset с kaggle: https://www.kaggle.com/datasets/ivan314sh/prices-of-moscow-apartments.

# %% [markdown]
# Устанавливаю необходимые библиотеки:

# %%
# !pip install seaborn
# !pip install kagglehub
# !pip install catboost
# !pip install pandas
# !pip install numpy
# !pip install matplotlib
# !pip install scikit-learn
# Out:
# Requirement already satisfied: seaborn in c:\games\важное\lib\site-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in c:\games\важное\lib\site-packages (from seaborn) (2.3.5)
# Requirement already satisfied: pandas>=1.2 in c:\games\важное\lib\site-packages (from seaborn) (2.3.3)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in c:\games\важное\lib\site-packages (from seaborn) (3.10.7)
# Requirement already satisfied: contourpy>=1.0.1 in c:\games\важное\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\games\важное\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\games\важное\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\games\важное\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in c:\users\1\appdata\roaming\python\python312\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (25.0)
# Requirement already satisfied: pillow>=8 in c:\games\важное\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (12.0.0)
# Requirement already satisfied: pyparsing>=3 in c:\games\важное\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\1\appdata\roaming\python\python312\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\games\важное\lib\site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\games\важное\lib\site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\1\appdata\roaming\python\python312\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)
# [notice] A new release of pip is available: 24.0 -> 25.3
# [notice] To update, run: C:\Games\Важное\python.exe -m pip install --upgrade pip
# Requirement already satisfied: kagglehub in c:\games\важное\lib\site-packages (0.3.13)
# Requirement already satisfied: packaging in c:\users\1\appdata\roaming\python\python312\site-packages (from kagglehub) (25.0)
# Requirement already satisfied: pyyaml in c:\games\важное\lib\site-packages (from kagglehub) (6.0.3)
# Requirement already satisfied: requests in c:\games\важное\lib\site-packages (from kagglehub) (2.32.5)
# Requirement already satisfied: tqdm in c:\games\важное\lib\site-packages (from kagglehub) (4.67.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\games\важное\lib\site-packages (from requests->kagglehub) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\games\важное\lib\site-packages (from requests->kagglehub) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\games\важное\lib\site-packages (from requests->kagglehub) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\games\важное\lib\site-packages (from requests->kagglehub) (2025.11.12)
# Requirement already satisfied: colorama in c:\users\1\appdata\roaming\python\python312\site-packages (from tqdm->kagglehub) (0.4.6)
# [notice] A new release of pip is available: 24.0 -> 25.3
# [notice] To update, run: C:\Games\Важное\python.exe -m pip install --upgrade pip
# Requirement already satisfied: catboost in c:\games\важное\lib\site-packages (1.2.8)
# Requirement already satisfied: graphviz in c:\games\важное\lib\site-packages (from catboost) (0.21)
# Requirement already satisfied: matplotlib in c:\games\важное\lib\site-packages (from catboost) (3.10.7)
# Requirement already satisfied: numpy<3.0,>=1.16.0 in c:\games\важное\lib\site-packages (from catboost) (2.3.5)
# Requirement already satisfied: pandas>=0.24 in c:\games\важное\lib\site-packages (from catboost) (2.3.3)
# Requirement already satisfied: scipy in c:\games\важное\lib\site-packages (from catboost) (1.16.3)
# Requirement already satisfied: plotly in c:\games\важное\lib\site-packages (from catboost) (6.5.0)
# Requirement already satisfied: six in c:\users\1\appdata\roaming\python\python312\site-packages (from catboost) (1.17.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\1\appdata\roaming\python\python312\site-packages (from pandas>=0.24->catboost) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\games\важное\lib\site-packages (from pandas>=0.24->catboost) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\games\важное\lib\site-packages (from pandas>=0.24->catboost) (2025.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\games\важное\lib\site-packages (from matplotlib->catboost) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\games\важное\lib\site-packages (from matplotlib->catboost) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\games\важное\lib\site-packages (from matplotlib->catboost) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\games\важное\lib\site-packages (from matplotlib->catboost) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in c:\users\1\appdata\roaming\python\python312\site-packages (from matplotlib->catboost) (25.0)
# Requirement already satisfied: pillow>=8 in c:\games\важное\lib\site-packages (from matplotlib->catboost) (12.0.0)
# Requirement already satisfied: pyparsing>=3 in c:\games\важное\lib\site-packages (from matplotlib->catboost) (3.2.5)
# Requirement already satisfied: narwhals>=1.15.1 in c:\games\важное\lib\site-packages (from plotly->catboost) (2.12.0)
# [notice] A new release of pip is available: 24.0 -> 25.3
# [notice] To update, run: C:\Games\Важное\python.exe -m pip install --upgrade pip
# Requirement already satisfied: pandas in c:\games\важное\lib\site-packages (2.3.3)
# Requirement already satisfied: numpy>=1.26.0 in c:\games\важное\lib\site-packages (from pandas) (2.3.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\1\appdata\roaming\python\python312\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\games\важное\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\games\важное\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\1\appdata\roaming\python\python312\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# [notice] A new release of pip is available: 24.0 -> 25.3
# [notice] To update, run: C:\Games\Важное\python.exe -m pip install --upgrade pip
# Requirement already satisfied: numpy in c:\games\важное\lib\site-packages (2.3.5)
# [notice] A new release of pip is available: 24.0 -> 25.3
# [notice] To update, run: C:\Games\Важное\python.exe -m pip install --upgrade pip
# Requirement already satisfied: matplotlib in c:\games\важное\lib\site-packages (3.10.7)
# Requirement already satisfied: contourpy>=1.0.1 in c:\games\важное\lib\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\games\важное\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\games\важное\lib\site-packages (from matplotlib) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\games\важное\lib\site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: numpy>=1.23 in c:\games\важное\lib\site-packages (from matplotlib) (2.3.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\1\appdata\roaming\python\python312\site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in c:\games\важное\lib\site-packages (from matplotlib) (12.0.0)
# Requirement already satisfied: pyparsing>=3 in c:\games\важное\lib\site-packages (from matplotlib) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\1\appdata\roaming\python\python312\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\1\appdata\roaming\python\python312\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# [notice] A new release of pip is available: 24.0 -> 25.3
# [notice] To update, run: C:\Games\Важное\python.exe -m pip install --upgrade pip
# Requirement already satisfied: scikit-learn in c:\games\важное\lib\site-packages (1.7.2)
# Requirement already satisfied: numpy>=1.22.0 in c:\games\важное\lib\site-packages (from scikit-learn) (2.3.5)
# Requirement already satisfied: scipy>=1.8.0 in c:\games\важное\lib\site-packages (from scikit-learn) (1.16.3)
# Requirement already satisfied: joblib>=1.2.0 in c:\games\важное\lib\site-packages (from scikit-learn) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\games\важное\lib\site-packages (from scikit-learn) (3.6.0)
# [notice] A new release of pip is available: 24.0 -> 25.3
# [notice] To update, run: C:\Games\Важное\python.exe -m pip install --upgrade pip

# %% [markdown]
# Импортирую нужные библиотеки:

# %%
import kagglehub
import pandas as pnd
import numpy as nmp
import matplotlib.pyplot as mpl
import seaborn as sbn
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error
from sklearn.preprocessing import StandardScaler
from catboost import CatBoostRegressor
import os

# %% [markdown]
# Загружаю датасет:

# %%
way=kagglehub.dataset_download("ivan314sh/prices-of-moscow-apartments")
print("Way to dataset files:", way)
# Out:
# Way to dataset files: C:\Users\1\.cache\kagglehub\datasets\ivan314sh\prices-of-moscow-apartments\versions\3

# %% [markdown]
# Смотрю данные:

# %%
way="C:\\Users\\1\\.cache\\kagglehub\\datasets\\ivan314sh\\prices-of-moscow-apartments\\versions\\3"
print(os.listdir(way))# Смотрю, какие файлы есть в папке
data=pnd.read_csv("C:\\Users\\1\\.cache\\kagglehub\\datasets\\ivan314sh\\prices-of-moscow-apartments\\versions\\3\\moscow_flats_dataset.csv", index_col=None)
data
# Out:
# ['moscow_flats_dataset.csv', 'moscow_flats_dataset_eng.csv']
#             price  min_to_metro region_of_moscow  total_area  living_area  \
# 0      31633073.0          24.0              ЮАО        64.2         32.4
# 1      29293000.0           9.0             СВАО        78.1          NaN
# 2      30349669.0           5.0              ЮАО        72.4         33.6
# 3      31845511.0          19.0              ЮАО        69.2          NaN
# 4      38810000.0          27.0              ЗАО        66.9         24.8
# ...           ...           ...              ...         ...          ...
# 6978   29504877.0           6.0              САО        86.1         49.5
# 6979  120000000.0           2.0              ЦАО       163.5         96.0
# 6980  165000000.0           7.0              ЦАО       154.0         76.0
# 6981   21500000.0          11.0             ЮВАО        94.2         69.0
# 6982   80000000.0           9.0              САО       139.0         86.0
#
#       floor  number_of_floors  construction_year  is_new  is_apartments  \
# 0      11.0              16.0             2023.0     1.0            0.0
# 1       9.0              27.0             2022.0     1.0            0.0
# 2       3.0              24.0             2023.0     1.0            0.0
# 3       2.0              12.0             2024.0     1.0            0.0
# 4       9.0              14.0             2023.0     1.0            0.0
# ...     ...               ...                ...     ...            ...
# 6978    3.0              12.0                NaN     0.0            0.0
# 6979    6.0               6.0             1998.0     0.0            0.0
# 6980   16.0              21.0             2023.0     0.0            0.0
# 6981    2.0               5.0                NaN     0.0            0.0
# 6982   13.0              14.0             2018.0     0.0            1.0
#
#       ceiling_height  number_of_rooms  \
# 0               3.15              2.0
# 1                NaN              2.0
# 2               3.15              2.0
# 3               2.97              2.0
# 4               3.00              2.0
# ...              ...              ...
# 6978             NaN              4.0
# 6979            3.00              4.0
# 6980             NaN              4.0
# 6981            2.80              4.0
# 6982            3.00              4.0
#
#                                           link
# 0     https://www.cian.ru/sale/flat/293204033/
# 1     https://www.cian.ru/sale/flat/294033524/
# 2     https://www.cian.ru/sale/flat/300712697/
# 3     https://www.cian.ru/sale/flat/300228448/
# 4     https://www.cian.ru/sale/flat/299262105/
# ...                                        ...
# 6978  https://www.cian.ru/sale/flat/298617209/
# 6979  https://www.cian.ru/sale/flat/297548153/
# 6980  https://www.cian.ru/sale/flat/295795425/
# 6981  https://www.cian.ru/sale/flat/300870085/
# 6982  https://www.cian.ru/sale/flat/299185566/
#
# [6983 rows x 13 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6983 entries, 0 to 6982
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   price              6961 non-null   float64
#  1   min_to_metro       6846 non-null   float64
#  2   region_of_moscow   6892 non-null   object
#  3   total_area         6960 non-null   float64
#  4   living_area        4514 non-null   float64
#  5   floor              6960 non-null   float64
#  6   number_of_floors   6960 non-null   float64
#  7   construction_year  5761 non-null   float64
#  8   is_new             6949 non-null   float64
#  9   is_apartments      6949 non-null   float64
#  10  ceiling_height     5053 non-null   float64
#  11  number_of_rooms    6983 non-null   float64
#  12  link               6983 non-null   object
# dtypes: float64(11), object(2)
# memory usage: 709.3+ KB

# %% [markdown]
# Проверяю датасет на наличие Nan:

# %%
data.isna().sum()
# Out:
# price                  22
# min_to_metro          137
# region_of_moscow       91
# total_area             23
# living_area          2469
# floor                  23
# number_of_floors       23
# construction_year    1222
# is_new                 34
# is_apartments          34
# ceiling_height       1930
# number_of_rooms         0
# link                    0
# dtype: int64

# %% [markdown]
# Заполню пропуски медианой, так как она устойчива к выбросам:

# %%
print(f"Пропусков в price до обработки: {data['price'].isnull().sum()}")
age_median = data['price'].median()
print(f"Медиана price: {age_median:.1f}")
data['price'].fillna(age_median, inplace=True)
print(f"Пропусков в price после обработки: {data['price'].isnull().sum()}")
print()
print(f"Пропусков в min_to_metro до обработки: {data['min_to_metro'].isnull().sum()}")
age_median = data['min_to_metro'].median()
print(f"Медиана min_to_metro: {age_median:.1f}")
data['min_to_metro'].fillna(age_median, inplace=True)
print(f"Пропусков в min_to_metro после обработки: {data['min_to_metro'].isnull().sum()}")
print()
print(f"Пропусков в total_area до обработки: {data['total_area'].isnull().sum()}")
age_median = data['total_area'].median()
print(f"Медиана total_area: {age_median:.1f}")
data['total_area'].fillna(age_median, inplace=True)
print(f"Пропусков в total_area после обработки: {data['total_area'].isnull().sum()}")
print()
print(f"Пропусков в living_area до обработки: {data['living_area'].isnull().sum()}")
age_median = data['living_area'].median()
print(f"Медиана living_area: {age_median:.1f}")
data['living_area'].fillna(age_median, inplace=True)
print(f"Пропусков в living_area после обработки: {data['living_area'].isnull().sum()}")
print()
print(f"Пропусков в floor до обработки: {data['floor'].isnull().sum()}")
age_median = data['floor'].median()
print(f"Медиана floor: {age_median:.1f}")
data['floor'].fillna(age_median, inplace=True)
print(f"Пропусков в floor после обработки: {data['floor'].isnull().sum()}")
print()
print(f"Пропусков в number_of_floors до обработки: {data['number_of_floors'].isnull().sum()}")
age_median = data['number_of_floors'].median()
print(f"Медиана number_of_floors: {age_median:.1f}")
data['number_of_floors'].fillna(age_median, inplace=True)
print(f"Пропусков в number_of_floors после обработки: {data['number_of_floors'].isnull().sum()}")
print()
print(f"Пропусков в construction_year до обработки: {data['construction_year'].isnull().sum()}")
age_median = data['construction_year'].median()
print(f"Медиана mconstruction_year: {age_median:.1f}")
data['construction_year'].fillna(age_median, inplace=True)
print(f"Пропусков в construction_year после обработки: {data['construction_year'].isnull().sum()}")
print()
print(f"Пропусков в is_new до обработки: {data['is_new'].isnull().sum()}")
age_median = data['is_new'].median()
print(f"Медиана is_new: {age_median:.1f}")
data['is_new'].fillna(age_median, inplace=True)
print(f"Пропусков в is_new после обработки: {data['is_new'].isnull().sum()}")
print()
print(f"Пропусков в is_apartments до обработки: {data['is_apartments'].isnull().sum()}")
age_median = data['is_apartments'].median()
print(f"Медиана is_apartments: {age_median:.1f}")
data['is_apartments'].fillna(age_median, inplace=True)
print(f"Пропусков в is_apartments после обработки: {data['is_apartments'].isnull().sum()}")
print()
print(f"Пропусков в ceiling_height до обработки: {data['ceiling_height'].isnull().sum()}")
age_median = data['ceiling_height'].median()
print(f"Медиана ceiling_height: {age_median:.1f}")
data['ceiling_height'].fillna(age_median, inplace=True)
print(f"Пропусков в ceiling_height после обработки: {data['ceiling_height'].isnull().sum()}")
# Out:
# Пропусков в price до обработки: 0
# Медиана price: 30500000.0
# Пропусков в price после обработки: 0
#
# Пропусков в min_to_metro до обработки: 0
# Медиана min_to_metro: 9.0
# Пропусков в min_to_metro после обработки: 0
#
# Пропусков в total_area до обработки: 0
# Медиана total_area: 70.8
# Пропусков в total_area после обработки: 0
#
# Пропусков в living_area до обработки: 0
# Медиана living_area: 37.5
# Пропусков в living_area после обработки: 0
#
# Пропусков в floor до обработки: 0
# Медиана floor: 7.0
# Пропусков в floor после обработки: 0
#
# Пропусков в number_of_floors до обработки: 0
# Медиана number_of_floors: 16.0
# Пропусков в number_of_floors после обработки: 0
#
# Пропусков в construction_year до обработки: 0
# Медиана mconstruction_year: 2019.0
# Пропусков в construction_year после обработки: 0
#
# Пропусков в is_new до обработки: 0
# Медиана is_new: 0.0
# Пропусков в is_new после обработки: 0
#
# Пропусков в is_apartments до обработки: 0
# Медиана is_apartments: 0.0
# Пропусков в is_apartments после обработки: 0
#
# Пропусков в ceiling_height до обработки: 0
# Медиана ceiling_height: 3.0
# Пропусков в ceiling_height после обработки: 0
# C:\Users\1\AppData\Local\Temp\ipykernel_23340\2042253824.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['price'].fillna(age_median, inplace=True)
# C:\Users\1\AppData\Local\Temp\ipykernel_23340\2042253824.py:10: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['min_to_metro'].fillna(age_median, inplace=True)
# C:\Users\1\AppData\Local\Temp\ipykernel_23340\2042253824.py:16: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['total_area'].fillna(age_median, inplace=True)
# C:\Users\1\AppData\Local\Temp\ipykernel_23340\2042253824.py:22: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['living_area'].fillna(age_median, inplace=True)
# C:\Users\1\AppData\Local\Temp\ipykernel_23340\2042253824.py:28: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['floor'].fillna(age_median, inplace=True)
# C:\Users\1\AppData\Local\Temp\ipykernel_23340\2042253824.py:34: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['number_of_floors'].fillna(age_median, inplace=True)
# C:\Users\1\AppData\Local\Temp\ipykernel_23340\2042253824.py:40: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['construction_year'].fillna(age_median, inplace=True)
# C:\Users\1\AppData\Local\Temp\ipykernel_23340\2042253824.py:46: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['is_new'].fillna(age_median, inplace=True)
# C:\Users\1\AppData\Local\Temp\ipykernel_23340\2042253824.py:52: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['is_apartments'].fillna(age_median, inplace=True)
# C:\Users\1\AppData\Local\Temp\ipykernel_23340\2042253824.py:58: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['ceiling_height'].fillna(age_median, inplace=True)

# %% [markdown]
# Так как region_of_moscow является категориальным признаком, я буду использовать немного другой код:

# %%
print(f"Пропусков в region_of_moscow до обработки: {data['region_of_moscow'].isnull().sum()}")
embarked_mode=data['region_of_moscow'].mode()[0]
print(f"Медиана region_of_moscow: {embarked_mode}")
data['region_of_moscow'].fillna(embarked_mode, inplace=True)
print(f"Пропусков в region_of_moscow после обработки: {data['region_of_moscow'].isnull().sum()}")
# Out:
# Пропусков в region_of_moscow до обработки: 91
# Медиана region_of_moscow: ЦАО
# Пропусков в region_of_moscow после обработки: 0
# C:\Users\1\AppData\Local\Temp\ipykernel_23340\3976735454.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['region_of_moscow'].fillna(embarked_mode, inplace=True)

# %% [markdown]
# Исследую данные:

# %%
print(data['region_of_moscow'].value_counts())
print(data['is_new'].value_counts())
print(data['is_apartments'].value_counts())
# Out:
# region_of_moscow
# ЦАО     1754
# ЗАО     1263
# СЗАО     724
# ЮАО      698
# САО      655
# СВАО     543
# ЮВАО     502
# ЮЗАО     467
# ВАО      377
# Name: count, dtype: int64
# is_new
# 0.0    5125
# 1.0    1858
# Name: count, dtype: int64
# is_apartments
# 0.0    5895
# 1.0    1088
# Name: count, dtype: int64

# %% [markdown]
# Замечу, что "region_of_moscow", "is_new", "is_apartments" являются категориальными признаками; "is_new", "is_apartments" могут принимать только значения "0" или "1", с ними все хорошо. Для переменной "region_of_moscow" применим One-Hot Encoding:

# %%
print("Значения region_of_moscow:")
print(data['region_of_moscow'].value_counts())
embarked_encoded=pnd.get_dummies(data['region_of_moscow'], prefix='region_of_moscow')
print(f"\nOne-Hot Encoding создал столбцы: {list(embarked_encoded.columns)}")
print("\nПервые 5 строк:")
print(embarked_encoded.head())
data_r=pnd.concat([data['region_of_moscow'], embarked_encoded], axis=1)
# Out:
# Значения region_of_moscow:
# region_of_moscow
# ЦАО     1754
# ЗАО     1263
# СЗАО     724
# ЮАО      698
# САО      655
# СВАО     543
# ЮВАО     502
# ЮЗАО     467
# ВАО      377
# Name: count, dtype: int64
#
# One-Hot Encoding создал столбцы: ['region_of_moscow_ВАО', 'region_of_moscow_ЗАО', 'region_of_moscow_САО', 'region_of_moscow_СВАО', 'region_of_moscow_СЗАО', 'region_of_moscow_ЦАО', 'region_of_moscow_ЮАО', 'region_of_moscow_ЮВАО', 'region_of_moscow_ЮЗАО']
#
# Первые 5 строк:
#    region_of_moscow_ВАО  region_of_moscow_ЗАО  region_of_moscow_САО  \
# 0                 False                 False                 False
# 1                 False                 False                 False
# 2                 False                 False                 False
# 3                 False                 False                 False
# 4                 False                  True                 False
#
#    region_of_moscow_СВАО  region_of_moscow_СЗАО  region_of_moscow_ЦАО  \
# 0                  False                  False                 False
# 1                   True                  False                 False
# 2                  False                  False                 False
# 3                  False                  False                 False
# 4                  False                  False                 False
#
#    region_of_moscow_ЮАО  region_of_moscow_ЮВАО  region_of_moscow_ЮЗАО
# 0                  True                  False                  False
# 1                 False                  False                  False
# 2                  True                  False                  False
# 3                  True                  False                  False
# 4                 False                  False                  False

# %%
print(data_r.value_counts())
# Out:
# region_of_moscow  region_of_moscow_ВАО  region_of_moscow_ЗАО  region_of_moscow_САО  region_of_moscow_СВАО  region_of_moscow_СЗАО  region_of_moscow_ЦАО  region_of_moscow_ЮАО  region_of_moscow_ЮВАО  region_of_moscow_ЮЗАО
# ЦАО               False                 False                 False                 False                  False                  True                  False                 False                  False                    1754
# ЗАО               False                 True                  False                 False                  False                  False                 False                 False                  False                    1263
# СЗАО              False                 False                 False                 False                  True                   False                 False                 False                  False                     724
# ЮАО               False                 False                 False                 False                  False                  False                 True                  False                  False                     698
# САО               False                 False                 True                  False                  False                  False                 False                 False                  False                     655
# СВАО              False                 False                 False                 True                   False                  False                 False                 False                  False                     543
# ЮВАО              False                 False                 False                 False                  False                  False                 False                 True                   False                     502
# ЮЗАО              False                 False                 False                 False                  False                  False                 False                 False                  True                      467
# ВАО               True                  False                 False                 False                  False                  False                 False                 False                  False                     377
# Name: count, dtype: int64

# %% [markdown]
# Добавляю полученные столбцы в общий датасет:

# %%
data=pnd.concat([data, data_r], axis=1)

# %%
data
# Out:
#             price  min_to_metro  region_of_moscow  total_area  living_area  \
# 0      31633073.0          24.0               ЮАО        64.2         32.4
# 1      29293000.0           9.0              СВАО        78.1         37.5
# 2      30349669.0           5.0               ЮАО        72.4         33.6
# 3      31845511.0          19.0               ЮАО        69.2         37.5
# 4      38810000.0          27.0               ЗАО        66.9         24.8
# ...           ...           ...               ...         ...          ...
# 6978   29504877.0           6.0               САО        86.1         49.5
# 6979  120000000.0           2.0               ЦАО       163.5         96.0
# 6980  165000000.0           7.0               ЦАО       154.0         76.0
# 6981   21500000.0          11.0              ЮВАО        94.2         69.0
# 6982   80000000.0           9.0               САО       139.0         86.0
#
#       floor  number_of_floors  construction_year  is_new  is_apartments  ...  \
# 0      11.0              16.0             2023.0     1.0            0.0  ...
# 1       9.0              27.0             2022.0     1.0            0.0  ...
# 2       3.0              24.0             2023.0     1.0            0.0  ...
# 3       2.0              12.0             2024.0     1.0            0.0  ...
# 4       9.0              14.0             2023.0     1.0            0.0  ...
# ...     ...               ...                ...     ...            ...  ...
# 6978    3.0              12.0             2019.0     0.0            0.0  ...
# 6979    6.0               6.0             1998.0     0.0            0.0  ...
# 6980   16.0              21.0             2023.0     0.0            0.0  ...
# 6981    2.0               5.0             2019.0     0.0            0.0  ...
# 6982   13.0              14.0             2018.0     0.0            1.0  ...
#
#       region_of_moscow  region_of_moscow_ВАО region_of_moscow_ЗАО  \
# 0                  ЮАО                 False                False
# 1                 СВАО                 False                False
# 2                  ЮАО                 False                False
# 3                  ЮАО                 False                False
# 4                  ЗАО                 False                 True
# ...                ...                   ...                  ...
# 6978               САО                 False                False
# 6979               ЦАО                 False                False
# 6980               ЦАО                 False                False
# 6981              ЮВАО                 False                False
# 6982               САО                 False                False
#
#      region_of_moscow_САО  region_of_moscow_СВАО  region_of_moscow_СЗАО  \
# 0                   False                  False                  False
# 1                   False                   True                  False
# 2                   False                  False                  False
# 3                   False                  False                  False
# 4                   False                  False                  False
# ...                   ...                    ...                    ...
# 6978                 True                  False                  False
# 6979                False                  False                  False
# 6980                False                  False                  False
# 6981                False                  False                  False
# 6982                 True                  False                  False
#
#       region_of_moscow_ЦАО  region_of_moscow_ЮАО  region_of_moscow_ЮВАО  \
# 0                    False                  True                  False
# 1                    False                 False                  False
# 2                    False                  True                  False
# 3                    False                  True                  False
# 4                    False                 False                  False
# ...                    ...                   ...                    ...
# 6978                 False                 False                  False
# 6979                  True                 False                  False
# 6980                  True                 False                  False
# 6981                 False                 False                   True
# 6982                 False                 False                  False
#
#       region_of_moscow_ЮЗАО
# 0                     False
# 1                     False
# 2                     False
# 3                     False
# 4                     False
# ...                     ...
# 6978                  False
# 6979                  False
# 6980                  False
# 6981                  False
# 6982                  False
#
# [6983 rows x 23 columns]

# %% [markdown]
# Удаляю ненужные столбцы:

# %%
data=data.drop(['region_of_moscow', 'link'], axis=1)
data_r = data_r.drop('region_of_moscow', axis=1)

# %%
data
# Out:
#             price  min_to_metro  total_area  living_area  floor  \
# 0      31633073.0          24.0        64.2         32.4   11.0
# 1      29293000.0           9.0        78.1         37.5    9.0
# 2      30349669.0           5.0        72.4         33.6    3.0
# 3      31845511.0          19.0        69.2         37.5    2.0
# 4      38810000.0          27.0        66.9         24.8    9.0
# ...           ...           ...         ...          ...    ...
# 6978   29504877.0           6.0        86.1         49.5    3.0
# 6979  120000000.0           2.0       163.5         96.0    6.0
# 6980  165000000.0           7.0       154.0         76.0   16.0
# 6981   21500000.0          11.0        94.2         69.0    2.0
# 6982   80000000.0           9.0       139.0         86.0   13.0
#
#       number_of_floors  construction_year  is_new  is_apartments  \
# 0                 16.0             2023.0     1.0            0.0
# 1                 27.0             2022.0     1.0            0.0
# 2                 24.0             2023.0     1.0            0.0
# 3                 12.0             2024.0     1.0            0.0
# 4                 14.0             2023.0     1.0            0.0
# ...                ...                ...     ...            ...
# 6978              12.0             2019.0     0.0            0.0
# 6979               6.0             1998.0     0.0            0.0
# 6980              21.0             2023.0     0.0            0.0
# 6981               5.0             2019.0     0.0            0.0
# 6982              14.0             2018.0     0.0            1.0
#
#       ceiling_height  number_of_rooms  region_of_moscow_ВАО  \
# 0               3.15              2.0                 False
# 1               3.00              2.0                 False
# 2               3.15              2.0                 False
# 3               2.97              2.0                 False
# 4               3.00              2.0                 False
# ...              ...              ...                   ...
# 6978            3.00              4.0                 False
# 6979            3.00              4.0                 False
# 6980            3.00              4.0                 False
# 6981            2.80              4.0                 False
# 6982            3.00              4.0                 False
#
#       region_of_moscow_ЗАО  region_of_moscow_САО  region_of_moscow_СВАО  \
# 0                    False                 False                  False
# 1                    False                 False                   True
# 2                    False                 False                  False
# 3                    False                 False                  False
# 4                     True                 False                  False
# ...                    ...                   ...                    ...
# 6978                 False                  True                  False
# 6979                 False                 False                  False
# 6980                 False                 False                  False
# 6981                 False                 False                  False
# 6982                 False                  True                  False
#
#       region_of_moscow_СЗАО  region_of_moscow_ЦАО  region_of_moscow_ЮАО  \
# 0                     False                 False                  True
# 1                     False                 False                 False
# 2                     False                 False                  True
# 3                     False                 False                  True
# 4                     False                 False                 False
# ...                     ...                   ...                   ...
# 6978                  False                 False                 False
# 6979                  False                  True                 False
# 6980                  False                  True                 False
# 6981                  False                 False                 False
# 6982                  False                 False                 False
#
#       region_of_moscow_ЮВАО  region_of_moscow_ЮЗАО
# 0                     False                  False
# 1                     False                  False
# 2                     False                  False
# 3                     False                  False
# 4                     False                  False
# ...                     ...                    ...
# 6978                  False                  False
# 6979                  False                  False
# 6980                  False                  False
# 6981                   True                  False
# 6982                  False                  False
#
# [6983 rows x 20 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6983 entries, 0 to 6982
# Data columns (total 20 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   price                  6983 non-null   float64
#  1   min_to_metro           6983 non-null   float64
#  2   total_area             6983 non-null   float64
#  3   living_area            6983 non-null   float64
#  4   floor                  6983 non-null   float64
#  5   number_of_floors       6983 non-null   float64
#  6   construction_year      6983 non-null   float64
#  7   is_new                 6983 non-null   float64
#  8   is_apartments          6983 non-null   float64
#  9   ceiling_height         6983 non-null   float64
#  10  number_of_rooms        6983 non-null   float64
#  11  region_of_moscow_ВАО   6983 non-null   bool
#  12  region_of_moscow_ЗАО   6983 non-null   bool
#  13  region_of_moscow_САО   6983 non-null   bool
#  14  region_of_moscow_СВАО  6983 non-null   bool
#  15  region_of_moscow_СЗАО  6983 non-null   bool
#  16  region_of_moscow_ЦАО   6983 non-null   bool
#  17  region_of_moscow_ЮАО   6983 non-null   bool
#  18  region_of_moscow_ЮВАО  6983 non-null   bool
#  19  region_of_moscow_ЮЗАО  6983 non-null   bool
# dtypes: bool(9), float64(11)
# memory usage: 661.6 KB

# %% [markdown]
# Продолжаю исследовать данные, строю тепловую карту корреляций:

# %%
mpl.figure(figsize=(12, 10))
# Создаю матрицу корреляций
correlation_matrix = data.corr()
# Тепловая карта корреляций
sbn.heatmap(correlation_matrix, annot=True, cmap='coolwarm', center=0,
            square=True, linewidths=0.5, cbar_kws={"shrink": .8})
mpl.title('Корреляционная матрица факторов квартир', fontsize=16)
mpl.tight_layout()
mpl.show()
print("Интерпретация:")
print("• Красный цвет = положительная корреляция (чем больше, тем больше)")
print("• Синий цвет = отрицательная корреляция (чем больше, тем меньше)")
print("• Близко к 0 = слабая связь")
# Out:
# Интерпретация:
# • Красный цвет = положительная корреляция (чем больше, тем больше)
# • Синий цвет = отрицательная корреляция (чем больше, тем меньше)
# • Близко к 0 = слабая связь

# %% [markdown]
# Замечу, что total_area имеет высокую положительную корреляцию на price:

# %%
mpl.figure(figsize=(10, 6))
mpl.scatter(data['total_area'], data['price'],
           alpha=0.7, color='blue', s=60)
mpl.title('Зависимость price от total_area', fontsize=16)
mpl.xlabel('total_area (м²)', fontsize=12)
mpl.ylabel('price (тыс. руб.)', fontsize=12)
mpl.grid(True, alpha=0.3)
mpl.show()
correlation = data['total_area'].corr(data['price'])
print(f"Корреляция между total_area и price: {correlation:.3f}")
print("(1.0 = идеальная положительная корреляция, 0 = нет связи)")
# Out:
# Корреляция между total_area и price: 0.749
# (1.0 = идеальная положительная корреляция, 0 = нет связи)

# %% [markdown]
# Проверяю данные на выбросы, построив для них гистограммы и boxplots:

# %%
for column in data.columns[1:7]:
    data.hist(column)
    mpl.show()

# %%
numeric_cols = ['min_to_metro', 'total_area', 'living_area', 'floor', 'number_of_floors', 'construction_year']
fig, axes = mpl.subplots(2, 3, figsize=(14, 10))
axes = axes.flatten()
for i, col in enumerate(numeric_cols):
    axes[i].boxplot(data[col].dropna())
    axes[i].set_title(f'Выбросы в {col}')
    axes[i].set_ylabel('Значение')
    axes[i].grid(True, alpha=0.3)
mpl.tight_layout()
mpl.show()

# %% [markdown]
# Удаляю выбросы:

# %%
'''функция для удаления выбросов'''
def clean_outliers(data, columns):
    for column in columns:
        Q1 = data[column].quantile(0.25)
        Q3 = data[column].quantile(0.75)
        IQR = Q3 - Q1
        lower_bound = Q1 - 1.5 * IQR
        upper_bound = Q3 + 1.5 * IQR

        #тут фильтруем наши данные
        data = data[(data[column] >= lower_bound) & (data[column] <= upper_bound)]

    return data

data = clean_outliers(data, ['min_to_metro', 'total_area', 'living_area', 'floor', 'number_of_floors', 'construction_year'])
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5360 entries, 0 to 6981
# Data columns (total 20 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   price                  5360 non-null   float64
#  1   min_to_metro           5360 non-null   float64
#  2   total_area             5360 non-null   float64
#  3   living_area            5360 non-null   float64
#  4   floor                  5360 non-null   float64
#  5   number_of_floors       5360 non-null   float64
#  6   construction_year      5360 non-null   float64
#  7   is_new                 5360 non-null   float64
#  8   is_apartments          5360 non-null   float64
#  9   ceiling_height         5360 non-null   float64
#  10  number_of_rooms        5360 non-null   float64
#  11  region_of_moscow_ВАО   5360 non-null   bool
#  12  region_of_moscow_ЗАО   5360 non-null   bool
#  13  region_of_moscow_САО   5360 non-null   bool
#  14  region_of_moscow_СВАО  5360 non-null   bool
#  15  region_of_moscow_СЗАО  5360 non-null   bool
#  16  region_of_moscow_ЦАО   5360 non-null   bool
#  17  region_of_moscow_ЮАО   5360 non-null   bool
#  18  region_of_moscow_ЮВАО  5360 non-null   bool
#  19  region_of_moscow_ЮЗАО  5360 non-null   bool
# dtypes: bool(9), float64(11)
# memory usage: 549.6 KB

# %% [markdown]
# Снова проверим данные на выбросы:

# %%
numeric_cols = ['min_to_metro', 'total_area', 'living_area', 'floor', 'number_of_floors', 'construction_year']
fig, axes = mpl.subplots(2, 3, figsize=(14, 10))
axes = axes.flatten()
for i, col in enumerate(numeric_cols):
    axes[i].boxplot(data[col].dropna())
    axes[i].set_title(f'Выбросы в {col}')
    axes[i].set_ylabel('Значение')
    axes[i].grid(True, alpha=0.3)
mpl.tight_layout()
mpl.show()

# %% [markdown]
# Имею картину гораздо лучше

# %% [markdown]
# Настало время создания и обучения моей модели:

# %%
from sklearn.preprocessing import StandardScaler
y = data['price']
X = data.drop(columns = ['price'])
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)
print(X_train)
# Out:
#       min_to_metro  total_area  living_area  floor  number_of_floors  \
# 2561          11.0        28.1         37.5    5.0              27.0
# 5018           9.0        86.0         37.5   15.0              23.0
# 5977          11.0        86.0         37.5    2.0               9.0
# 3997           9.0       110.0         52.8    2.0              18.0
# 1992          16.0        45.0         26.0    2.0              12.0
# ...            ...         ...          ...    ...               ...
# 3508           4.0        39.0         18.9    4.0              17.0
# 4398           7.0        68.9         46.0    6.0              17.0
# 6694          15.0       190.0         37.5    8.0              11.0
# 6752          15.0        61.0         42.9    6.0               9.0
# 1015           6.0        37.0         22.6    5.0               9.0
#
#       construction_year  is_new  is_apartments  ceiling_height  \
# 2561             2022.0     0.0            0.0            3.00
# 5018             2015.0     0.0            0.0            3.00
# 5977             2018.0     0.0            0.0            3.00
# 3997             2023.0     1.0            0.0            2.80
# 1992             1972.0     0.0            0.0            2.64
# ...                 ...     ...            ...             ...
# 3508             2004.0     0.0            0.0            2.70
# 4398             2019.0     0.0            1.0            3.10
# 6694             2020.0     0.0            0.0            3.30
# 6752             2019.0     0.0            0.0            3.00
# 1015             1962.0     0.0            0.0            2.64
#
#       number_of_rooms  region_of_moscow_ВАО  region_of_moscow_ЗАО  \
# 2561              1.0                 False                 False
# 5018              3.0                 False                  True
# 5977              4.0                 False                 False
# 3997              3.0                 False                 False
# 1992              2.0                 False                  True
# ...               ...                   ...                   ...
# 3508              1.0                 False                 False
# 4398              3.0                 False                 False
# 6694              4.0                 False                  True
# 6752              4.0                 False                 False
# 1015              2.0                 False                 False
#
#       region_of_moscow_САО  region_of_moscow_СВАО  region_of_moscow_СЗАО  \
# 2561                 False                  False                  False
# 5018                 False                  False                  False
# 5977                 False                  False                  False
# 3997                 False                  False                  False
# 1992                 False                  False                  False
# ...                    ...                    ...                    ...
# 3508                 False                  False                  False
# 4398                  True                  False                  False
# 6694                 False                  False                  False
# 6752                  True                  False                  False
# 1015                  True                  False                  False
#
#       region_of_moscow_ЦАО  region_of_moscow_ЮАО  region_of_moscow_ЮВАО  \
# 2561                 False                 False                   True
# 5018                 False                 False                  False
# 5977                 False                 False                   True
# 3997                 False                  True                  False
# 1992                 False                 False                  False
# ...                    ...                   ...                    ...
# 3508                 False                  True                  False
# 4398                 False                 False                  False
# 6694                 False                 False                  False
# 6752                 False                 False                  False
# 1015                 False                 False                  False
#
#       region_of_moscow_ЮЗАО
# 2561                  False
# 5018                  False
# 5977                  False
# 3997                  False
# 1992                  False
# ...                     ...
# 3508                  False
# 4398                  False
# 6694                  False
# 6752                  False
# 1015                  False
#
# [4020 rows x 19 columns]

# %%
model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# Замеряю метрики:

# %%
y_pred = model.predict(X_test)
mse = mean_squared_error(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)
print("MSE:", mse)
print("MAE:", mae)
print("R2:", r2)
# Out:
# MSE: 861722189422337.5
# MAE: 16302989.357588422
# R2: 0.7204320758116882

# %% [markdown]
# Результаты не самые впечатляющие.

# %% [markdown]
# Попробую еще использовать Ridge регрессию с перебором гиперпараметров:

# %%
from sklearn.linear_model import Ridge
from sklearn.model_selection import GridSearchCV
ridge = Ridge()
param_grid = {
    'alpha': [0.1, 1, 10, 100],  # Варьируем уровень регуляризации
    'solver': ['auto', 'svd', 'cholesky', 'lsqr']  # Выбор оптимизатора
}
grid_search = GridSearchCV(
    estimator=ridge,
    param_grid=param_grid,
    cv=5,
    scoring='neg_mean_squared_error',
    verbose=1
)
grid_search.fit(X_train, y_train)
print("Лучшие параметры:", grid_search.best_params_)
# Out:
# Fitting 5 folds for each of 16 candidates, totalling 80 fits
# Лучшие параметры: {'alpha': 1, 'solver': 'auto'}

# %% [markdown]
# В очередной раз замерим метрики:

# %%
best_model = grid_search.best_estimator_
y_pred = best_model.predict(X_test)
mse = mean_squared_error(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)
print("MSE:", mse)
print("MAE:", mae)
print("R2:", r2)
# Out:
# MSE: 861738138896277.4
# MAE: 16301678.339914279
# R2: 0.7204269013350693

# %% [markdown]
# Результат почти не изменился, по этой причине не буду использовать Ridge регрессию.

# %% [markdown]
# С регрессией не получается добиться достаточно высоких метрик, попробую создать и обучить случайный лес:

# %%
from sklearn.ensemble import RandomForestRegressor
model2 = RandomForestRegressor(n_estimators=100, random_state=42)
model2.fit(X_train, y_train)
y_pred = model2.predict(X_test)
mse = mean_squared_error(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)
print("MSE:", mse)
print("MAE:", mae)
print("R2:", r2)
# Out:
# MSE: 470490547945668.7
# MAE: 9202241.127148896
# R2: 0.8473590822495044

# %% [markdown]
# Небольшим перебором гиперпараметра (n_estimators) нам удалось получить результат сильно лучше, чем в LinearRegression.

# %% [markdown]
# Добился хороших метрик, пожалуй остановлюсь на данной модели.

# %% [markdown]
# Сохраню модель

# %%
import pickle
with open('random_forest_model.pkl', 'wb') as f:
    pickle.dump(model, f)

# %% [markdown]
# Проверю корректность работы:

# %%
# Данные для предсказания
x_new = [[20, 65, 30, 15, 2025, 5, 1, 0, 3, 2, False, False, False, False, False, True, False, False, False]]

forest_features = [11, 12, 13, 14, 15, 16, 17, 18, 19]  # Индексы категориальных признаков

# Загрузка модели
with open('random_forest_model.pkl', 'rb') as f:
    loaded_model = pickle.load(f)

# Используем загруженную модель для предсказаний
prediction = loaded_model.predict(x_new)
print(prediction)
# Out:
# [59787415.07310539]
# c:\Users\1\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
